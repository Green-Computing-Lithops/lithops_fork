# %% [markdown]
# # π Estimation with Monte Carlo methods
# We demonstrate how to run Monte Carlo simulations with lithops over IBM Cloud Functions. This notebook contains an example of estimation the number π with Monte Carlo. The goal of this notebook is to demonstrate how IBM Cloud Functions can benefit Monte Carlo simulations and not how it can be done using lithops.<br>
# A Monte Carlo algorithm would randomly place points in the square and use the percentage of randomized points inside of the circle to estimate the value of π
# ![pi](https://upload.wikimedia.org/wikipedia/commons/8/84/Pi_30K.gif)
# Requirements to run this notebook:
#
# * AWS Cloud or GCP account.
# * You will need to have at least one existing object storage bucket.

# %% [markdown]
# # Step 1 - Install dependencies
# Install dependencies

# %%
from time import time
from random import random
import logging
import sys

try:
    import lithops
except:
    # %pip install -r requirements.txt
    import lithops

# you can modify logging level if needed
#logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # Step 2 - Write Python code that implements Monte Carlo simulation
# Below is an example of Python code to demonstrate Monte Carlo model for estimate PI
#
# 'EstimatePI' is a Python class that we use to represent a single PI estimation. You may configure the following parameters:
#
# MAP_INSTANCES - number of cloud functions invocations. Default is 100<br>
# randomize_per_map - number of points to random in a single invocation. Default is 10,000,000
#
# Our code contains two major Python methods:
#
# def randomize_points(self,data=None) - a function to random number of points and return the percentage of points
#     that inside the circle<br>
# def process_in_circle_points(self, results, futures): - summarize results of all randomize_points
#   executions (aka "reduce" in map-reduce paradigm)

# %%
MAP_INSTANCES = 1000


class EstimatePI:
    randomize_per_map = 10000000

    def __init__(self):
        self.total_randomize_points = MAP_INSTANCES * self.randomize_per_map

    def __str__(self):
        return "Total Randomize Points: {:,}".format(self.randomize_per_map * MAP_INSTANCES)

    @staticmethod
    def predicate():
        x = random()
        y = random()
        return (x ** 2) + (y ** 2) <= 1

    def randomize_points(self, data):
        in_circle = 0
        for _ in range(self.randomize_per_map):
            in_circle += self.predicate()
        return float(in_circle / self.randomize_per_map)

    def process_in_circle_points(self, results):
        in_circle_percent = 0
        for map_result in results:
            in_circle_percent += map_result
        estimate_PI = float(4 * (in_circle_percent / MAP_INSTANCES))
        return estimate_PI

# %% [markdown]
# # Step 3 - Configure access to your Cloud Storage and Cloud Functions
#
# Configure access details to your AWS or other cloud provider.  'storage_bucket'  should point to some pre-existing bucket. This bucket will be used by Lithops to store intermediate results. All results will be stored in the folder `lithops.jobs`.
#
# e.g. for GCP your `.lithops_config` should be similar to:
#
#     lithops:
#         storage: gcp_storage
#         backend: gcp_functions
#         bucket: lithops-pipelines
#
#     gcp:
#         credentials_path : <PATH_TO_JSON_KEYS>
#         region : <GCP_REGION>
#
#     gcp_functions:
#         region : <GCP_REGION>
#
#     gcp_storage:
#         region: <GCP_REGION>
#         storage_bucket: <GCP_STORAGE_BUCKET>
#
# For AWS your `.lithops_config` should be similar to:
#
#     lithops:
#         storage: aws_s3
#         backend: aws_lambda
#
#     aws:
#         access_key_id : <AWS_ACCESS_KEY_ID>
#         secret_access_key : <AWS_SECRET_ACCESS_KEY>
#
#     aws_s3:
#         storage_bucket: <S3_BUCKET>
#         region_name : <REGION>
#
#     aws_lambda:
#         execution_role: <AWS_ROLE_ARN>
#         region_name: <REGION>

# %% [markdown]
# # Step 4 - Execute simulation with Lithops over IBM Cloud Functions

# %%
iterdata = [0] * MAP_INSTANCES # funcion + iterable --> length ( numero de elementos )
est_pi = EstimatePI()

start_time = time()
print("Monte Carlo simulation for estimating PI spawing over {} Cloud Function invocations".format(MAP_INSTANCES))
# obtain lithops executor
pw = lithops.FunctionExecutor(runtime_memory=2048)

# execute the code
pw.map_reduce(est_pi.randomize_points, iterdata, est_pi.process_in_circle_points, spawn_reducer=100) # iterdata :  spawn_reducer
#get results
result = pw.get_result()
elapsed = time()
print(str(est_pi))
print("Estimation of Pi: ", result)
print("\nCompleted in: " + str(elapsed - start_time) + " seconds")
# 20% de los maps lanza el reduce --> solapar entrada y salida --> para ir midiendo spawn_reducer --> cambiar  
#
# Out:
# 2025-03-28 10:31:28,539 [INFO] config.py:139 -- Lithops v3.6.1.dev0 - Python3.12
# 2025-03-28 10:31:28,539 [INFO] localhost.py:39 -- Localhost storage client created
# 2025-03-28 10:31:28,539 [INFO] localhost.py:78 -- Localhost compute v2 client created
# 2025-03-28 10:31:28,549 [INFO] invokers.py:119 -- ExecutorID e85945-3 | JobID M000 - Selected Runtime: python - 2048MB
# 2025-03-28 10:31:28,625 [INFO] invokers.py:186 -- ExecutorID e85945-3 | JobID M000 - Starting function invocation: randomize_points() - Total: 1000 activations
# Monte Carlo simulation for estimating PI spawing over 1000 Cloud Function invocations
# 2025-03-28 10:31:29,348 [INFO] invokers.py:225 -- ExecutorID e85945-3 | JobID M000 - View execution logs at /tmp/lithops-bigrobbin/logs/e85945-3-M000.log
# 2025-03-28 10:31:29,361 [INFO] wait.py:101 -- ExecutorID e85945-3 - Waiting for 1000 function activations to complete
#     0%|          | 0/1000
# 2025-03-28 10:33:54,058 [INFO] executors.py:618 -- ExecutorID e85945-3 - Cleaning temporary data
# 2025-03-28 10:33:54,061 [INFO] invokers.py:119 -- ExecutorID e85945-3 | JobID R000 - Selected Runtime: python - 2048MB
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[32], line 10
#       7 pw = lithops.FunctionExecutor(runtime_memory=2048)
#       9 # execute the code
# ---> 10 pw.map_reduce(est_pi.randomize_points, iterdata, est_pi.process_in_circle_points, spawn_reducer=100) # iterdata :  spawn_reducer
#      11 #get results
#      12 result = pw.get_result()
#
# File ~/Desktop/TFG/lithops/lithops/executors.py:373, in FunctionExecutor.map_reduce(self, map_function, map_iterdata, reduce_function, chunksize, extra_args, extra_args_reduce, extra_env, map_runtime_memory, reduce_runtime_memory, timeout, obj_chunk_size, obj_chunk_number, obj_newline, obj_reduce_by_key, spawn_reducer, include_modules, exclude_modules)
#     369 reduce_job_id = map_job_id.replace('M', 'R')
#     371 runtime_meta = self.invoker.select_runtime(reduce_job_id, reduce_runtime_memory)
# --> 373 reduce_job = create_reduce_job(
#     374     config=self.config,
#     375     internal_storage=self.internal_storage,
#     376     executor_id=self.executor_id,
#     377     reduce_job_id=reduce_job_id,
#     378     reduce_function=reduce_function,
#     379     map_job=map_job,
#     380     map_futures=map_futures,
#     381     runtime_meta=runtime_meta,
#     382     runtime_memory=reduce_runtime_memory,
#     383     extra_args=extra_args_reduce,
#     384     obj_reduce_by_key=obj_reduce_by_key,
#     385     extra_env=extra_env,
#     386     include_modules=include_modules,
#     387     exclude_modules=exclude_modules
#     388 )
#     390 reduce_futures = self.invoker.run_job(reduce_job)
#     391 self.futures.extend(reduce_futures)
#
# File ~/Desktop/TFG/lithops/lithops/job/job.py:144, in create_reduce_job(config, internal_storage, executor_id, reduce_job_id, reduce_function, map_job, map_futures, runtime_meta, runtime_memory, obj_reduce_by_key, extra_env, include_modules, exclude_modules, execution_timeout, extra_args)
#     140     ext_env.update(reduce_job_env)
#     142 iterdata = utils.verify_args(reduce_function, iterdata, extra_args)
# --> 144 return _create_job(
#     145     config=config,
#     146     internal_storage=internal_storage,
#     147     executor_id=executor_id,
#     148     job_id=reduce_job_id,
#     149     func=reduce_function,
#     150     iterdata=iterdata,
#     151     runtime_meta=runtime_meta,
#     152     runtime_memory=runtime_memory,
#     153     extra_env=ext_env,
#     154     include_modules=include_modules,
#     155     exclude_modules=exclude_modules,
#     156     execution_timeout=execution_timeout,
#     157     host_job_meta=host_job_meta
#     158 )
#
# File ~/Desktop/TFG/lithops/lithops/job/job.py:265, in _create_job(config, internal_storage, executor_id, job_id, func, iterdata, runtime_meta, runtime_memory, extra_env, include_modules, exclude_modules, execution_timeout, host_job_meta, chunksize)
#     262 if data_limit and data_size_bytes > data_limit * 1024**2:
#     263     log_msg = ('ExecutorID {} | JobID {} - Total data exceeded maximum size '
#     264                'of {}'.format(executor_id, job_id, utils.sizeof_fmt(data_limit * 1024**2)))
# --> 265     raise Exception(log_msg)
#     267 # Upload function and data
#     268 upload_function = not config[backend].get("runtime_include_function", False)
#
# Exception: ExecutorID e85945-3 | JobID R000 - Total data exceeded maximum size of 4.0MiB

# %% [markdown]
# # multiple queries / values
# 2025-03-27 20:49:35,134 [INFO] config.py:139 -- Lithops v3.6.1.dev0 - Python3.12
# 2025-03-27 20:49:35,134 [INFO] localhost.py:39 -- Localhost storage client created
# 2025-03-27 20:49:35,134 [INFO] localhost.py:78 -- Localhost compute v2 client created
# 2025-03-27 20:49:35,153 [INFO] invokers.py:119 -- ExecutorID 5b7526-4 | JobID M000 - Selected Runtime: python - 2048MB
# 2025-03-27 20:49:35,235 [INFO] invokers.py:186 -- ExecutorID 5b7526-4 | JobID M000 - Starting function invocation: randomize_points() - Total: 1000 activations
# Monte Carlo simulation for estimating PI spawing over 1000 Cloud Function invocations
# 2025-03-27 20:49:35,966 [INFO] invokers.py:225 -- ExecutorID 5b7526-4 | JobID M000 - View execution logs at /tmp/lithops-bigrobbin/logs/5b7526-4-M000.log
# 2025-03-27 20:49:35,977 [INFO] wait.py:105 -- ExecutorID 5b7526-4 - Waiting for 20% of 1000 function activations to complete
# ## 0%|          | 0/200
#
# 2025-03-27 20:50:05,731 [INFO] invokers.py:119 -- ExecutorID 5b7526-4 | JobID R000 - Selected Runtime: python - 2048MB
# 2025-03-27 20:50:05,770 [INFO] invokers.py:186 -- ExecutorID 5b7526-4 | JobID R000 - Starting function invocation: process_in_circle_points() - Total: 1 activations
# 2025-03-27 20:50:05,771 [INFO] invokers.py:225 -- ExecutorID 5b7526-4 | JobID R000 - View execution logs at /tmp/lithops-bigrobbin/logs/5b7526-4-R000.log
# 2025-03-27 20:50:05,772 [INFO] executors.py:494 -- ExecutorID 5b7526-4 - Getting results from 1 function activations
# 2025-03-27 20:50:05,779 [INFO] wait.py:101 -- ExecutorID 5b7526-4 - Waiting for 801 function activations to complete
#
# ## 0%|          | 0/801
#
# Total Randomize Points: 10,000,000,000
# Estimation of Pi:  3.1422579999999742
#
# Completed in: 143.96522045135498 seconds

# %%
# Price in AWS
import numpy as np

stats = [f.stats for f in pw.futures]
stats2 = [f.stats for f in pw.futures] # save to understand 

mean_exec_time = np.mean([stat['worker_func_exec_time'] for stat in stats])

# Debug: Print the structure of worker_func_perf_energy to understand what's in it
if stats and 'worker_func_perf_energy' in stats[0]:
    print(f"Structure of worker_func_perf_energy: {stats[0]['worker_func_perf_energy']}")

# Handle worker_func_perf_energy as a dictionary
# If it's a dictionary, we need to extract a specific value or calculate an aggregate
try:
    # Option 1: If there's a specific key we want to extract from each dictionary
    # For example, if each dictionary has a 'total' or 'value' key
    if stats and 'worker_func_perf_energy' in stats[0] and isinstance(stats[0]['worker_func_perf_energy'], dict):
        # Try to find a numeric key in the dictionary
        sample_dict = stats[0]['worker_func_perf_energy']
        numeric_keys = [k for k, v in sample_dict.items() if isinstance(v, (int, float))]
        
        if numeric_keys:
            # Use the first numeric key found
            key_to_use = numeric_keys[0]
            worker_func_perf_energy = np.mean([stat['worker_func_perf_energy'][key_to_use] 
                                              for stat in stats 
                                              if 'worker_func_perf_energy' in stat 
                                              and key_to_use in stat['worker_func_perf_energy']])
            print(f"Using key '{key_to_use}' from worker_func_perf_energy dictionary")
        else:
            # If no numeric keys found, skip this calculation
            worker_func_perf_energy = "N/A (No numeric values found in dictionary)"
    else:
        # If it's not a dictionary or doesn't exist, skip this calculation
        worker_func_perf_energy = "N/A"
        
except Exception as e:
    print(f"Error processing worker_func_perf_energy: {e}")
    worker_func_perf_energy = "N/A (Error)"

print(f"Perf Energy: {worker_func_perf_energy}")
# print(f"Global Perf Energy: {pw.stats.get('worker_func_perf_energy', 'N/A')}")

gbxms_price = 0.0000000167
sum_total_time = sum([stat['worker_exec_time'] for stat in stats]) * 1000
price = gbxms_price * sum_total_time * 0.256  # Price GB/ms * sum of times in ms * 0.256 GB runtime

print(f'Experiment total price is {round(price, 5)} USD')
# Out:
# Structure of worker_func_perf_energy: {'pkg': 706.6, 'cores': 682.73, 'total': 1389.33}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 645.9909634551495
# Experiment total price is 0.00441 USD

# %% [markdown]
# for MAP_INSTANCES = 50
# Structure of worker_func_perf_energy: {'pkg': 606.06, 'cores': 579.64, 'total': 1185.6999999999998}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 494.1625490196078
# Experiment total price is 0.00062 USD
#
# for MAP_INSTANCES = 100
# Structure of worker_func_perf_energy: {'pkg': 574.76, 'cores': 557.8, 'total': 1132.56}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 611.191188118812
# Experiment total price is 0.00131 USD
#
#
# for MAP_INSTANCES = 200
# Structure of worker_func_perf_energy: {'pkg': 630.99, 'cores': 604.2, 'total': 1235.19}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 562.0333333333333
# Experiment total price is 0.00759 USD
#
#
# for MAP_INSTANCES = 300
# Structure of worker_func_perf_energy: {'pkg': 630.99, 'cores': 604.2, 'total': 1235.19}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 562.0333333333333
# Experiment total price is 0.00759 USD
#
# for MAP_INSTANCES = 500
# Structure of worker_func_perf_energy: {'pkg': 630.99, 'cores': 604.2, 'total': 1235.19}
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 562.0333333333333
# Experiment total price is 0.00759 USD
#
# for MAP_INSTANCES = 5000
# Exception: ExecutorID 5b7526-1 | JobID R000 - Total data exceeded maximum size of 4.0MiB

# %%
# problems where are multiple splits 
if stats and 'worker_func_perf_energy' in stats[1]:
    print(f"Structure of worker_func_perf_energy: {stats[1]['worker_func_perf_energy']}")


print(stats)
# Handle worker_func_perf_energy as a dictionary
# If it's a dictionary, we need to extract a specific value or calculate an aggregate
try:
    # Option 1: If there's a specific key we want to extract from each dictionary
    # For example, if each dictionary has a 'total' or 'value' key
    if stats and 'worker_func_perf_energy' in stats[1] and isinstance(stats[0]['worker_func_perf_energy'], dict):
        # Try to find a numeric key in the dictionary
        sample_dict = stats[0]['worker_func_perf_energy']
        numeric_keys = [k for k, v in sample_dict.items() if isinstance(v, (int, float))]
        
        if numeric_keys:
            # Use the first numeric key found
            key_to_use = numeric_keys[0]
            worker_func_perf_energy = np.sum([stat['worker_func_perf_energy'][key_to_use] 
                                              for stat in stats 
                                              if 'worker_func_perf_energy' in stat 
                                              and key_to_use in stat['worker_func_perf_energy']])
            print(f"Using key '{key_to_use}' from worker_func_perf_energy dictionary")
        else:
            # If no numeric keys found, skip this calculation
            worker_func_perf_energy = "N/A (No numeric values found in dictionary)"
    else:
        # If it's not a dictionary or doesn't exist, skip this calculation
        worker_func_perf_energy = "N/A"
        
except Exception as e:
    print(f"Error processing worker_func_perf_energy: {e}")
    worker_func_perf_energy = "N/A (Error)"

print(f"Perf Energy: {worker_func_perf_energy}")
# print(f"Global Perf Energy: {pw.stats.get('worker_func_perf_energy', 'N/A')}")
# Out:
# Structure of worker_func_perf_energy: {'pkg': 627.71, 'cores': 608.57, 'total': 1236.2800000000002}
# [{'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.4829373, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2235286, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.0, 99.7, 99.3, 100.0, 99.0, 100.0, 100.0, 99.7, 99.0, 99.3, 100.0, 98.7, 99.7, 100.0, 100.0, 99.0, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.14, 'worker_func_cpu_user_time': 4630.63, 'worker_func_avg_cpu_usage': 99.68214285714285, 'worker_func_energy_consumption': 461591.1211785714, 'worker_func_sent_net_io': 525320, 'worker_func_recv_net_io': 749688, 'worker_func_rss': 50065408, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.958139657974243, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 706.6, 'worker_func_energy_cores': 682.73, 'worker_func_energy_total': 1389.33, 'worker_func_perf_energy': {'pkg': 706.6, 'cores': 682.73, 'total': 1389.33}, 'worker_func_perf_energy_pkg': 706.6, 'worker_func_perf_energy_cores': 682.73, 'worker_func_energy_efficiency': 469.6634238531604, 'worker_peak_memory_start': 36130816.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3522785, 'worker_func_end_tstamp': 1743152372.2917564, 'worker_func_exec_time': 2.93947792, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37507072.0, 'worker_end_tstamp': 1743152372.4327967, 'worker_exec_time': 3.20926809, 'host_result_done_tstamp': 1743152372.536209, 'host_result_query_count': 0}, {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.9944806, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1940377, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.6, 99.6, 99.2, 100.0, 98.8, 100.0, 100.0, 99.6, 98.8, 99.2, 100.0, 98.4, 99.6, 100.0, 100.0, 98.8, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.4, 'worker_func_cpu_user_time': 4616.19, 'worker_func_avg_cpu_usage': 99.61428571428571, 'worker_func_energy_consumption': 459838.46957142855, 'worker_func_sent_net_io': 506158, 'worker_func_recv_net_io': 225970, 'worker_func_rss': 50454528, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.410123109817505, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 627.71, 'worker_func_energy_cores': 608.57, 'worker_func_energy_total': 1236.2800000000002, 'worker_func_perf_energy': {'pkg': 627.71, 'cores': 608.57, 'total': 1236.2800000000002}, 'worker_func_perf_energy_pkg': 627.71, 'worker_func_perf_energy_cores': 608.57, 'worker_func_energy_efficiency': 512.9530499766096, 'worker_peak_memory_start': 35676160.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3494265, 'worker_func_end_tstamp': 1743152371.7496119, 'worker_func_exec_time': 2.40018535, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37281792.0, 'worker_end_tstamp': 1743152371.874403, 'worker_exec_time': 2.68036532, 'host_result_done_tstamp': 1743152372.024432, 'host_result_query_count': 0}, {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e ...
# Using key 'pkg' from worker_func_perf_energy dictionary
# Perf Energy: 194443.28000000003

# %%
for stat_test in stats2:
    print(stat_test)
    print("\n")


print(stats2.__len__())
print(pw.futures.__len__())
# Out:
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.4829373, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2235286, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.0, 99.7, 99.3, 100.0, 99.0, 100.0, 100.0, 99.7, 99.0, 99.3, 100.0, 98.7, 99.7, 100.0, 100.0, 99.0, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.14, 'worker_func_cpu_user_time': 4630.63, 'worker_func_avg_cpu_usage': 99.68214285714285, 'worker_func_energy_consumption': 461591.1211785714, 'worker_func_sent_net_io': 525320, 'worker_func_recv_net_io': 749688, 'worker_func_rss': 50065408, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.958139657974243, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 706.6, 'worker_func_energy_cores': 682.73, 'worker_func_energy_total': 1389.33, 'worker_func_perf_energy': {'pkg': 706.6, 'cores': 682.73, 'total': 1389.33}, 'worker_func_perf_energy_pkg': 706.6, 'worker_func_perf_energy_cores': 682.73, 'worker_func_energy_efficiency': 469.6634238531604, 'worker_peak_memory_start': 36130816.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3522785, 'worker_func_end_tstamp': 1743152372.2917564, 'worker_func_exec_time': 2.93947792, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37507072.0, 'worker_end_tstamp': 1743152372.4327967, 'worker_exec_time': 3.20926809, 'host_result_done_tstamp': 1743152372.536209, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.9944806, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1940377, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.6, 99.6, 99.2, 100.0, 98.8, 100.0, 100.0, 99.6, 98.8, 99.2, 100.0, 98.4, 99.6, 100.0, 100.0, 98.8, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.4, 'worker_func_cpu_user_time': 4616.19, 'worker_func_avg_cpu_usage': 99.61428571428571, 'worker_func_energy_consumption': 459838.46957142855, 'worker_func_sent_net_io': 506158, 'worker_func_recv_net_io': 225970, 'worker_func_rss': 50454528, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.410123109817505, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 627.71, 'worker_func_energy_cores': 608.57, 'worker_func_energy_total': 1236.2800000000002, 'worker_func_perf_energy': {'pkg': 627.71, 'cores': 608.57, 'total': 1236.2800000000002}, 'worker_func_perf_energy_pkg': 627.71, 'worker_func_perf_energy_cores': 608.57, 'worker_func_energy_efficiency': 512.9530499766096, 'worker_peak_memory_start': 35676160.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3494265, 'worker_func_end_tstamp': 1743152371.7496119, 'worker_func_exec_time': 2.40018535, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37281792.0, 'worker_end_tstamp': 1743152371.874403, 'worker_exec_time': 2.68036532, 'host_result_done_tstamp': 1743152372.024432, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.5056698, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.0893683, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.1, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.8, 99.7, 100.0, 100.0, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.17, 'worker_func_cpu_user_time': 4631.04, 'worker_func_avg_cpu_usage': 99.70714285714287, 'worker_func_energy_consumption': 461747.7668571429, 'worker_func_sent_net_io': 525433, 'worker_func_recv_net_io': 749688, 'worker_func_rss': 49795072, 'worker_func_vms': 1065709568, 'worker_func_uss': 31498240, 'worker_func_energy_duration': 3.0917370319366455, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 739.53, 'worker_func_energy_cores': 714.95, 'worker_func_energy_total': 1454.48, 'worker_func_perf_energy': {'pkg': 739.53, 'cores': 714.95, 'total': 1454.48}, 'worker_func_perf_energy_pkg': 739.53, 'worker_func_perf_energy_cores': 714.95, 'worker_func_energy_efficiency': 470.4410449451849, 'worker_peak_memory_start': 36261888.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.239179, 'worker_func_end_tstamp': 1743152372.30784, 'worker_func_exec_time': 3.06866121, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37867520.0, 'worker_end_tstamp': 1743152372.4562674, 'worker_exec_time': 3.36689901, 'host_result_done_tstamp': 1743152372.5359306, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.475507, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1653888, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.1, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.0, 99.4, 100.0, 98.7, 99.7, 100.0, 100.0, 99.0, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.17, 'worker_func_cpu_user_time': 4631.26, 'worker_func_avg_cpu_usage': 99.69642857142857, 'worker_func_energy_consumption': 461720.0817857143, 'worker_func_sent_net_io': 525763, 'worker_func_recv_net_io': 749893, 'worker_func_rss': 50069504, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.0132062435150146, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 719.74, 'worker_func_energy_cores': 695.45, 'worker_func_energy_total': 1415.19, 'worker_func_perf_energy': {'pkg': 719.74, 'cores': 695.45, 'total': 1415.19}, 'worker_func_perf_energy_pkg': 719.74, 'worker_func_perf_energy_cores': 695.45, 'worker_func_energy_efficiency': 469.6625075186123, 'worker_peak_memory_start': 35790848.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3123, 'worker_func_end_tstamp': 1743152372.312149, 'worker_func_exec_time': 2.99984908, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37396480.0, 'worker_end_tstamp': 1743152372.4440958, 'worker_exec_time': 3.27870703, 'host_result_done_tstamp': 1743152372.5363336, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.6761703, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1661777, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.7, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.2, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.21, 'worker_func_cpu_user_time': 4611.12, 'worker_func_avg_cpu_usage': 99.88214285714285, 'worker_func_energy_consumption': 460568.54657142854, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 49967104, 'worker_func_vms': 1065660416, 'worker_func_uss': 31363072, 'worker_func_energy_duration': 2.2943572998046875, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 594.8, 'worker_func_energy_cores': 577.01, 'worker_func_energy_total': 1171.81, 'worker_func_perf_energy': {'pkg': 594.8, 'cores': 577.01, 'total': 1171.81}, 'worker_func_perf_energy_pkg': 594.8, 'worker_func_perf_energy_cores': 577.01, 'worker_func_energy_efficiency': 510.73562086417536, 'worker_peak_memory_start': 35672064.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3028524, 'worker_func_end_tstamp': 1743152371.552268, 'worker_func_exec_time': 2.24941564, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37277696.0, 'worker_end_tstamp': 1743152371.6718404, 'worker_exec_time': 2.50566268, 'host_result_done_tstamp': 1743152371.6994665, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.6724942, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2252553, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.9, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.8, 99.7, 100.0, 99.7, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.47, 'worker_func_cpu_user_time': 4636.48, 'worker_func_avg_cpu_usage': 99.68928571428572, 'worker_func_energy_consumption': 462207.3794285714, 'worker_func_sent_net_io': 533462, 'worker_func_recv_net_io': 759408, 'worker_func_rss': 50081792, 'worker_func_vms': 1065660416, 'worker_func_uss': 31379456, 'worker_func_energy_duration': 3.1724061965942383, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 760.74, 'worker_func_energy_cores': 734.94, 'worker_func_energy_total': 1495.68, 'worker_func_perf_energy': {'pkg': 760.74, 'cores': 734.94, 'total': 1495.68}, 'worker_func_perf_energy_pkg': 760.74, 'worker_func_perf_energy_cores': 734.94, 'worker_func_energy_efficiency': 471.4654767746007, 'worker_peak_memory_start': 35909632.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3565516, 'worker_func_end_tstamp': 1743152372.5136678, 'worker_func_exec_time': 3.15711617, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37515264.0, 'worker_end_tstamp': 1743152372.646198, 'worker_exec_time': 3.42094278, 'host_result_done_tstamp': 1743152372.7616477, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.4824955, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1959426, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.0, 99.7, 99.3, 100.0, 99.0, 100.0, 100.0, 99.7, 99.0, 99.3, 100.0, 98.7, 99.7, 100.0, 100.0, 99.0, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.06, 'worker_func_cpu_user_time': 4629.19, 'worker_func_avg_cpu_usage': 99.68214285714285, 'worker_func_energy_consumption': 461447.57889285707, 'worker_func_sent_net_io': 524033, 'worker_func_recv_net_io': 702044, 'worker_func_rss': 49827840, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 2.9170470237731934, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 700.8, 'worker_func_energy_cores': 677.36, 'worker_func_energy_total': 1378.1599999999999, 'worker_func_perf_energy': {'pkg': 700.8, 'cores': 677.36, 'total': 1378.1599999999999}, 'worker_func_perf_energy_pkg': 700.8, 'worker_func_perf_energy_cores': 677.36, 'worker_func_energy_efficiency': 472.45038861847115, 'worker_peak_memory_start': 35733504.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3443084, 'worker_func_end_tstamp': 1743152372.2361925, 'worker_func_exec_time': 2.89188409, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37339136.0, 'worker_end_tstamp': 1743152372.3560014, 'worker_exec_time': 3.16005874, 'host_result_done_tstamp': 1743152372.5361266, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.7085412, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2010694, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [96.7, 99.4, 98.5, 99.7, 98.2, 100.0, 99.1, 99.7, 98.5, 99.4, 100.0, 97.9, 99.1, 100.0, 99.4, 98.8, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.67, 'worker_func_cpu_user_time': 4638.13, 'worker_func_avg_cpu_usage': 99.43214285714285, 'worker_func_energy_consumption': 461179.20475, 'worker_func_sent_net_io': 540244, 'worker_func_recv_net_io': 766190, 'worker_func_rss': 50085888, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.2544548511505127, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 778.49, 'worker_func_energy_cores': 752.03, 'worker_func_energy_total': 1530.52, 'worker_func_perf_energy': {'pkg': 778.49, 'cores': 752.03, 'total': 1530.52}, 'worker_func_perf_energy_pkg': 778.49, 'worker_func_perf_energy_cores': 752.03, 'worker_func_energy_efficiency': 470.2846006479185, 'worker_peak_memory_start': 35901440.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3504076, 'worker_func_end_tstamp': 1743152372.5886438, 'worker_func_exec_time': 3.23823619, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37507072.0, 'worker_end_tstamp': 1743152372.7040477, 'worker_exec_time': 3.50297832, 'host_result_done_tstamp': 1743152372.7618508, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.8245149, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2986448, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.7, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.1, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.24, 'worker_func_cpu_user_time': 4612.19, 'worker_func_avg_cpu_usage': 99.87857142857142, 'worker_func_energy_consumption': 460658.9483571428, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 49819648, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.2331061363220215, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 586.53, 'worker_func_energy_cores': 568.85, 'worker_func_energy_total': 1155.38, 'worker_func_perf_energy': {'pkg': 586.53, 'cores': 568.85, 'total': 1155.38}, 'worker_func_perf_energy_pkg': 586.53, 'worker_func_perf_energy_cores': 568.85, 'worker_func_energy_efficiency': 517.3869621364877, 'worker_peak_memory_start': 35676160.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.375275, 'worker_func_end_tstamp': 1743152371.5931957, 'worker_func_exec_time': 2.21792078, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37281792.0, 'worker_end_tstamp': 1743152371.7087455, 'worker_exec_time': 2.4101007, 'host_result_done_tstamp': 1743152371.910795, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.653981, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1518388, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [99.1, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.1, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.14, 'worker_func_cpu_user_time': 4609.05, 'worker_func_avg_cpu_usage': 99.92142857142858, 'worker_func_energy_consumption': 460542.8603571429, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 50290688, 'worker_func_vms': 1065660416, 'worker_func_uss': 31383552, 'worker_func_energy_duration': 2.2388370037078857, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 587.23, 'worker_func_energy_cores': 569.77, 'worker_func_energy_total': 1157.0, 'worker_func_perf_energy': {'pkg': 587.23, 'cores': 569.77, 'total': 1157.0}, 'worker_func_perf_energy_pkg': 587.23, 'worker_func_perf_energy_cores': 569.77, 'worker_func_energy_efficiency': 516.7861698211241, 'worker_peak_memory_start': 35909632.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2740867, 'worker_func_end_tstamp': 1743152371.4762607, 'worker_func_exec_time': 2.20217395, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37515264.0, 'worker_end_tstamp': 1743152371.5971167, 'worker_exec_time': 2.44527793, 'host_result_done_tstamp': 1743152371.699813, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.668458, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2918692, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.8, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.8, 99.7, 100.0, 99.7, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.48, 'worker_func_cpu_user_time': 4636.51, 'worker_func_avg_cpu_usage': 99.68571428571428, 'worker_func_energy_consumption': 462193.8111428571, 'worker_func_sent_net_io': 533462, 'worker_func_recv_net_io': 759408, 'worker_func_rss': 49823744, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 3.1604368686676025, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 755.9, 'worker_func_energy_cores': 729.85, 'worker_func_energy_total': 1485.75, 'worker_func_perf_energy': {'pkg': 755.9, 'cores': 729.85, 'total': 1485.75}, 'worker_func_perf_energy_pkg': 755.9, 'worker_func_perf_energy_cores': 729.85, 'worker_func_energy_efficiency': 470.10905825382684, 'worker_peak_memory_start': 35729408.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3687327, 'worker_func_end_tstamp': 1743152372.5148735, 'worker_func_exec_time': 3.14614081, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37335040.0, 'worker_end_tstamp': 1743152372.6529598, 'worker_exec_time': 3.36109066, 'host_result_done_tstamp': 1743152372.7619474, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.65388, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.0312097, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [99.2, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.12, 'worker_func_cpu_user_time': 4607.94, 'worker_func_avg_cpu_usage': 99.95714285714287, 'worker_func_energy_consumption': 460596.51685714285, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 50511872, 'worker_func_vms': 1065689088, 'worker_func_uss': 31461376, 'worker_func_energy_duration': 2.264707565307617, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 595.2, 'worker_func_energy_cores': 577.5, 'worker_func_energy_total': 1172.7, 'worker_func_perf_energy': {'pkg': 595.2, 'cores': 577.5, 'total': 1172.7}, 'worker_func_perf_energy_pkg': 595.2, 'worker_func_perf_energy_cores': 577.5, 'worker_func_energy_efficiency': 517.8151996152807, 'worker_peak_memory_start': 36143104.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2064686, 'worker_func_end_tstamp': 1743152371.4356816, 'worker_func_exec_time': 2.229213, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37748736.0, 'worker_end_tstamp': 1743152371.5569005, 'worker_exec_time': 2.52569079, 'host_result_done_tstamp': 1743152371.7000027, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.464496, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.3894825, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.9, 99.6, 99.3, 100.0, 98.9, 100.0, 100.0, 99.6, 98.9, 99.3, 100.0, 98.6, 99.6, 100.0, 100.0, 98.9, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.04, 'worker_func_cpu_user_time': 4628.99, 'worker_func_avg_cpu_usage': 99.64999999999999, 'worker_func_energy_consumption': 461278.8534999999, 'worker_func_sent_net_io': 524033, 'worker_func_recv_net_io': 702044, 'worker_func_rss': 50249728, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 2.8103268146514893, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 672.26, 'worker_func_energy_cores': 649.47, 'worker_func_energy_total': 1321.73, 'worker_func_perf_energy': {'pkg': 672.26, 'cores': 649.47, 'total': 1321.73}, 'worker_func_perf_energy_pkg': 672.26, 'worker_func_perf_energy_cores': 649.47, 'worker_func_energy_efficiency': 470.3118488245677, 'worker_peak_memory_start': 36130816.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.427295, 'worker_func_end_tstamp': 1743152372.2289672, 'worker_func_exec_time': 2.80167222, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37507072.0, 'worker_end_tstamp': 1743152372.363038, 'worker_exec_time': 2.97355556, 'host_result_done_tstamp': 1743152372.5366995, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.8534982, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1262157, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.0, 99.6, 99.2, 100.0, 98.8, 100.0, 100.0, 99.6, 99.2, 99.2, 100.0, 98.4, 99.6, 100.0, 100.0, 98.8, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.38, 'worker_func_cpu_user_time': 4615.52, 'worker_func_avg_cpu_usage': 99.64285714285714, 'worker_func_energy_consumption': 459903.60000000003, 'worker_func_sent_net_io': 502254, 'worker_func_recv_net_io': 77970, 'worker_func_rss': 50356224, 'worker_func_vms': 1065701376, 'worker_func_uss': 31485952, 'worker_func_energy_duration': 2.416341781616211, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 628.87, 'worker_func_energy_cores': 609.77, 'worker_func_energy_total': 1238.6399999999999, 'worker_func_perf_energy': {'pkg': 628.87, 'cores': 609.77, 'total': 1238.6399999999999}, 'worker_func_perf_energy_pkg': 628.87, 'worker_func_perf_energy_cores': 609.77, 'worker_func_energy_efficiency': 512.6096024261578, 'worker_peak_memory_start': 35848192.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3407545, 'worker_func_end_tstamp': 1743152371.7235785, 'worker_func_exec_time': 2.38282394, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37453824.0, 'worker_end_tstamp': 1743152371.837551, 'worker_exec_time': 2.71133542, 'host_result_done_tstamp': 1743152371.9146488, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.8225996, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.0212145, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.5, 99.6, 100.0, 100.0, 99.6, 100.0, 100.0, 99.6, 100.0, 99.6, 100.0, 99.6, 100.0, 100.0, 100.0, 98.9, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.29, 'worker_func_cpu_user_time': 4613.36, 'worker_func_avg_cpu_usage': 99.82142857142857, 'worker_func_energy_consumption': 460512.18571428565, 'worker_func_sent_net_io': 473963, 'worker_func_recv_net_io': 41443, 'worker_func_rss': 50294784, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 2.4674839973449707, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 643.36, 'worker_func_energy_cores': 623.94, 'worker_func_energy_total': 1267.3000000000002, 'worker_func_perf_energy': {'pkg': 643.36, 'cores': 623.94, 'total': 1267.3000000000002}, 'worker_func_perf_energy_pkg': 643.36, 'worker_func_perf_energy_cores': 623.94, 'worker_func_energy_efficiency': 513.6000887396325, 'worker_peak_memory_start': 35958784.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.1929011, 'worker_func_end_tstamp': 1743152371.6382473, 'worker_func_exec_time': 2.44534612, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37335040.0, 'worker_end_tstamp': 1743152371.7582421, 'worker_exec_time': 2.73702765, 'host_result_done_tstamp': 1743152371.910922, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.7862074, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2495735, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [96.4, 99.4, 97.9, 99.7, 97.9, 100.0, 98.8, 99.7, 97.9, 99.4, 99.7, 97.9, 98.8, 100.0, 99.4, 98.8, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.71, 'worker_func_cpu_user_time': 4639.0, 'worker_func_avg_cpu_usage': 99.33571428571429, 'worker_func_energy_consumption': 460818.3785714286, 'worker_func_sent_net_io': 540244, 'worker_func_recv_net_io': 766190, 'worker_func_rss': 49651712, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.277998924255371, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 787.23, 'worker_func_energy_cores': 760.46, 'worker_func_energy_total': 1547.69, 'worker_func_perf_energy': {'pkg': 787.23, 'cores': 760.46, 'total': 1547.69}, 'worker_func_perf_energy_pkg': 787.23, 'worker_func_perf_energy_cores': 760.46, 'worker_func_energy_efficiency': 472.1447553103065, 'worker_peak_memory_start': 35729408.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.360141, 'worker_func_end_tstamp': 1743152372.6207821, 'worker_func_exec_time': 3.2606411, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37335040.0, 'worker_end_tstamp': 1743152372.7507281, 'worker_exec_time': 3.50115466, 'host_result_done_tstamp': 1743152372.7879722, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.8134885, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.3313136, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.7, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.1, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.26, 'worker_func_cpu_user_time': 4612.62, 'worker_func_avg_cpu_usage': 99.87857142857142, 'worker_func_energy_consumption': 460701.8961428571, 'worker_func_sent_net_io': 473354, 'worker_func_recv_net_io': 40636, 'worker_func_rss': 50368512, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.240952491760254, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 588.94, 'worker_func_energy_cores': 571.15, 'worker_func_energy_total': 1160.0900000000001, 'worker_func_perf_energy': {'pkg': 588.94, 'cores': 571.15, 'total': 1160.0900000000001}, 'worker_func_perf_energy_pkg': 588.94, 'worker_func_perf_energy_cores': 571.15, 'worker_func_energy_efficiency': 517.677194972017, 'worker_peak_memory_start': 35905536.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3822234, 'worker_func_end_tstamp': 1743152371.6096506, 'worker_func_exec_time': 2.22742724, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37281792.0, 'worker_end_tstamp': 1743152371.7323709, 'worker_exec_time': 2.40105724, 'host_result_done_tstamp': 1743152371.914785, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.5347304, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.167603, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.1, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.8, 99.7, 100.0, 100.0, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.28, 'worker_func_cpu_user_time': 4633.23, 'worker_func_avg_cpu_usage': 99.70714285714287, 'worker_func_energy_consumption': 461966.1255, 'worker_func_sent_net_io': 533079, 'worker_func_recv_net_io': 756223, 'worker_func_rss': 50270208, 'worker_func_vms': 1065660416, 'worker_func_uss': 31367168, 'worker_func_energy_duration': 3.119544744491577, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 739.91, 'worker_func_energy_cores': 714.89, 'worker_func_energy_total': 1454.8, 'worker_func_perf_energy': {'pkg': 739.91, 'cores': 714.89, 'total': 1454.8}, 'worker_func_perf_energy_pkg': 739.91, 'worker_func_perf_energy_cores': 714.89, 'worker_func_energy_efficiency': 466.3500988626156, 'worker_peak_memory_start': 36126720.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2957458, 'worker_func_end_tstamp': 1743152372.3865712, 'worker_func_exec_time': 3.09082532, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37502976.0, 'worker_end_tstamp': 1743152372.5129302, 'worker_exec_time': 3.34532714, 'host_result_done_tstamp': 1743152372.5385625, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.5310347, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2257378, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.1, 99.7, 99.4, 100.0, 99.0, 100.0, 100.0, 99.7, 99.0, 99.4, 100.0, 98.7, 99.7, 100.0, 100.0, 99.0, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.27, 'worker_func_cpu_user_time': 4632.93, 'worker_func_avg_cpu_usage': 99.69285714285715, 'worker_func_energy_consumption': 461870.0286428572, 'worker_func_sent_net_io': 532809, 'worker_func_recv_net_io': 754417, 'worker_func_rss': 49483776, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.030532121658325, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 723.72, 'worker_func_energy_cores': 699.16, 'worker_func_energy_total': 1422.88, 'worker_func_perf_energy': {'pkg': 723.72, 'cores': 699.16, 'total': 1422.88}, 'worker_func_perf_energy_pkg': 723.72, 'worker_func_perf_energy_cores': 699.16, 'worker_func_energy_efficiency': 469.5149046040772, 'worker_peak_memory_start': 36130816.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3606262, 'worker_func_end_tstamp': 1743152372.3793516, 'worker_func_exec_time': 3.0187254, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37507072.0, 'worker_end_tstamp': 1743152372.5055337, 'worker_exec_time': 3.27979589, 'host_result_done_tstamp': 1743152372.5365944, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.822554, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.2398243, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.7, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.1, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.25, 'worker_func_cpu_user_time': 4612.29, 'worker_func_avg_cpu_usage': 99.87857142857142, 'worker_func_energy_consumption': 460668.93621428567, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 50065408, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.284135341644287, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 597.95, 'worker_func_energy_cores': 579.98, 'worker_func_energy_total': 1177.93, 'worker_func_perf_energy': {'pkg': 597.95, 'cores': 579.98, 'total': 1177.93}, 'worker_func_perf_energy_pkg': 597.95, 'worker_func_perf_energy_cores': 579.98, 'worker_func_energy_efficiency': 515.7006148120979, 'worker_peak_memory_start': 35676160.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.339279, 'worker_func_end_tstamp': 1743152371.5980926, 'worker_func_exec_time': 2.25881362, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37281792.0, 'worker_end_tstamp': 1743152371.718132, 'worker_exec_time': 2.47830772, 'host_result_done_tstamp': 1743152371.9148915, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.9825459, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.3107517, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.6, 99.6, 99.2, 100.0, 98.8, 100.0, 100.0, 99.6, 98.8, 99.2, 100.0, 98.4, 99.6, 100.0, 100.0, 98.8, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.51, 'worker_func_cpu_user_time': 4618.58, 'worker_func_avg_cpu_usage': 99.61428571428571, 'worker_func_energy_consumption': 460076.5477142857, 'worker_func_sent_net_io': 511953, 'worker_func_recv_net_io': 565258, 'worker_func_rss': 50384896, 'worker_func_vms': 1066074112, 'worker_func_uss': 31780864, 'worker_func_energy_duration': 2.472994565963745, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 644.35, 'worker_func_energy_cores': 624.5, 'worker_func_energy_total': 1268.85, 'worker_func_perf_energy': {'pkg': 644.35, 'cores': 624.5, 'total': 1268.85}, 'worker_func_perf_energy_pkg': 644.35, 'worker_func_perf_energy_cores': 624.5, 'worker_func_energy_efficiency': 513.0824052197297, 'worker_peak_memory_start': 36311040.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3748636, 'worker_func_end_tstamp': 1743152371.8378718, 'worker_func_exec_time': 2.46300817, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37916672.0, 'worker_end_tstamp': 1743152371.9636734, 'worker_exec_time': 2.65292168, 'host_result_done_tstamp': 1743152372.025205, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.724472, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.0976038, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.9, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.8, 99.7, 100.0, 99.7, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.5, 'worker_func_cpu_user_time': 4636.59, 'worker_func_avg_cpu_usage': 99.68928571428572, 'worker_func_energy_consumption': 462218.34525, 'worker_func_sent_net_io': 533462, 'worker_func_recv_net_io': 759408, 'worker_func_rss': 50274304, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.2749478816986084, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 782.41, 'worker_func_energy_cores': 755.98, 'worker_func_energy_total': 1538.3899999999999, 'worker_func_perf_energy': {'pkg': 782.41, 'cores': 755.98, 'total': 1538.3899999999999}, 'worker_func_perf_energy_pkg': 782.41, 'worker_func_perf_energy_cores': 755.98, 'worker_func_energy_efficiency': 469.74488009320237, 'worker_peak_memory_start': 36044800.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2850287, 'worker_func_end_tstamp': 1743152372.5181305, 'worker_func_exec_time': 3.23310184, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37421056.0, 'worker_end_tstamp': 1743152372.6943371, 'worker_exec_time': 3.59673333, 'host_result_done_tstamp': 1743152372.7626345, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.7204695, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152368.9210815, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.1, 99.7, 99.2, 100.0, 98.9, 100.0, 100.0, 99.7, 99.2, 99.4, 100.0, 98.9, 99.7, 100.0, 99.7, 99.2, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.58, 'worker_func_cpu_user_time': 4637.21, 'worker_func_avg_cpu_usage': 99.69285714285715, 'worker_func_energy_consumption': 462296.71407142864, 'worker_func_sent_net_io': 540244, 'worker_func_recv_net_io': 766190, 'worker_func_rss': 50499584, 'worker_func_vms': 1065844736, 'worker_func_uss': 31657984, 'worker_func_energy_duration': 3.3642079830169678, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 804.15, 'worker_func_energy_cores': 776.99, 'worker_func_energy_total': 1581.1399999999999, 'worker_func_perf_energy': {'pkg': 804.15, 'cores': 776.99, 'total': 1581.1399999999999}, 'worker_func_perf_energy_pkg': 804.15, 'worker_func_perf_energy_cores': 776.99, 'worker_func_energy_efficiency': 469.9887783341085, 'worker_peak_memory_start': 36085760.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2070704, 'worker_func_end_tstamp': 1743152372.544402, 'worker_func_exec_time': 3.33733153, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37691392.0, 'worker_end_tstamp': 1743152372.6664436, 'worker_exec_time': 3.74536204, 'host_result_done_tstamp': 1743152372.7627513, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152372.750817, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.3344555, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [97.8, 99.7, 99.4, 100.0, 99.1, 100.0, 100.0, 99.7, 99.1, 99.4, 100.0, 98.7, 99.7, 100.0, 99.7, 99.1, 99.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 932.5, 'worker_func_cpu_user_time': 4636.62, 'worker_func_avg_cpu_usage': 99.68214285714285, 'worker_func_energy_consumption': 462188.2172142857, 'worker_func_sent_net_io': 533462, 'worker_func_recv_net_io': 759408, 'worker_func_rss': 49807360, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 3.1430907249450684, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 749.74, 'worker_func_energy_cores': 724.17, 'worker_func_energy_total': 1473.9099999999999, 'worker_func_perf_energy': {'pkg': 749.74, 'cores': 724.17, 'total': 1473.9099999999999}, 'worker_func_perf_energy_pkg': 749.74, 'worker_func_perf_energy_cores': 724.17, 'worker_func_energy_efficiency': 468.936511536987, 'worker_peak_memory_start': 35958784.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.3894017, 'worker_func_end_tstamp': 1743152372.5193768, 'worker_func_exec_time': 3.12997508, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37335040.0, 'worker_end_tstamp': 1743152372.7171237, 'worker_exec_time': 3.38266826, 'host_result_done_tstamp': 1743152372.7880962, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152371.6540518, 'host_status_query_count': 1, 'worker_start_tstamp': 1743152369.1737514, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [98.7, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.1, 99.6, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], 'worker_func_cpu_system_time': 931.17, 'worker_func_cpu_user_time': 4610.16, 'worker_func_avg_cpu_usage': 99.89285714285714, 'worker_func_energy_consumption': 460522.0542857142, 'worker_func_sent_net_io': 473178, 'worker_func_recv_net_io': 40565, 'worker_func_rss': 50270208, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.2708489894866943, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 592.65, 'worker_func_energy_cores': 575.22, 'worker_func_energy_total': 1167.87, 'worker_func_perf_energy': {'pkg': 592.65, 'cores': 575.22, 'total': 1167.87}, 'worker_func_perf_energy_pkg': 592.65, 'worker_func_perf_energy_cores': 575.22, 'worker_func_energy_efficiency': 514.2878304135876, 'worker_peak_memory_start': 35913728.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152369.2713737, 'worker_func_end_tstamp': 1743152371.5172393, 'worker_func_exec_time': 2.24586558, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37519360.0, 'worker_end_tstamp': 1743152371.631962, 'worker_exec_time': 2.45821071, 'host_result_done_tstamp': 1743152371.699924, 'host_result_query_count': 0}
#
#
# ...
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.5316606, 'host_status_query_count': 31, 'worker_start_tstamp': 1743152408.1881442, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [36.5, 87.4, 49.5, 79.7, 58.4, 73.3, 62.0, 68.9, 79.6, 58.9, 46.8, 82.4, 68.3, 58.7, 87.0, 68.9, 89.2, 90.0, 88.3, 89.2, 79.0, 84.3, 85.1, 83.8, 68.8, 68.5, 69.4, 72.4], 'worker_func_cpu_system_time': 959.44, 'worker_func_cpu_user_time': 5645.61, 'worker_func_avg_cpu_usage': 72.65357142857142, 'worker_func_energy_consumption': 410173.7293928571, 'worker_func_sent_net_io': 3342, 'worker_func_recv_net_io': 11936, 'worker_func_rss': 50032640, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.167928457260132, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.1, 'worker_func_energy_pkg': 436.02, 'worker_func_energy_cores': 418.6, 'worker_func_energy_total': 854.62, 'worker_func_perf_energy': {'pkg': 436.02, 'cores': 418.6, 'total': 854.62}, 'worker_func_perf_energy_pkg': 436.02, 'worker_func_perf_energy_cores': 418.6, 'worker_func_energy_efficiency': 394.210425689086, 'worker_peak_memory_start': 35733504.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.2593513, 'worker_func_end_tstamp': 1743152410.41233, 'worker_func_exec_time': 2.15297866, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37339136.0, 'worker_end_tstamp': 1743152410.5194438, 'worker_exec_time': 2.33129954, 'host_result_done_tstamp': 1743152410.5588422, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.2983289, 'host_status_query_count': 26, 'worker_start_tstamp': 1743152408.1762655, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [41.7, 91.8, 46.9, 91.8, 67.2, 74.5, 66.3, 75.3, 79.3, 67.2, 47.7, 91.8, 75.1, 62.3, 87.2, 79.4, 100.0, 100.0, 98.5, 100.0, 89.5, 95.4, 96.4, 95.4, 78.2, 78.2, 78.4, 82.5], 'worker_func_cpu_system_time': 959.26, 'worker_func_cpu_user_time': 5643.72, 'worker_func_avg_cpu_usage': 79.92857142857143, 'worker_func_energy_consumption': 451094.47714285715, 'worker_func_sent_net_io': 1477, 'worker_func_recv_net_io': 9381, 'worker_func_rss': 49975296, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 1.8909590244293213, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 397.02, 'worker_func_energy_cores': 381.75, 'worker_func_energy_total': 778.77, 'worker_func_perf_energy': {'pkg': 397.02, 'cores': 381.75, 'total': 778.77}, 'worker_func_perf_energy_pkg': 397.02, 'worker_func_perf_energy_cores': 381.75, 'worker_func_energy_efficiency': 411.83864374587785, 'worker_peak_memory_start': 36139008.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.242908, 'worker_func_end_tstamp': 1743152410.118933, 'worker_func_exec_time': 1.87602496, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37515264.0, 'worker_end_tstamp': 1743152410.2282872, 'worker_exec_time': 2.05202174, 'host_result_done_tstamp': 1743152410.3553038, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.0878954, 'host_status_query_count': 22, 'worker_start_tstamp': 1743152408.307757, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [39.8, 92.7, 42.2, 96.9, 72.0, 69.4, 63.4, 81.6, 83.4, 66.5, 42.2, 100.0, 74.5, 64.4, 84.7, 87.0, 100.0, 100.0, 100.0, 100.0, 94.4, 100.0, 100.0, 100.0, 82.6, 84.0, 85.1, 89.0], 'worker_func_cpu_system_time': 959.18, 'worker_func_cpu_user_time': 5641.27, 'worker_func_avg_cpu_usage': 81.99285714285715, 'worker_func_energy_consumption': 462543.8452142858, 'worker_func_sent_net_io': 1415, 'worker_func_recv_net_io': 9321, 'worker_func_rss': 49905664, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 1.5838000774383545, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 334.73, 'worker_func_energy_cores': 322.03, 'worker_func_energy_total': 656.76, 'worker_func_perf_energy': {'pkg': 334.73, 'cores': 322.03, 'total': 656.76}, 'worker_func_perf_energy_pkg': 334.73, 'worker_func_perf_energy_cores': 322.03, 'worker_func_energy_efficiency': 414.6735496201305, 'worker_peak_memory_start': 35905536.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.371791, 'worker_func_end_tstamp': 1743152409.9316406, 'worker_func_exec_time': 1.55984974, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37511168.0, 'worker_end_tstamp': 1743152410.0414922, 'worker_exec_time': 1.73373532, 'host_result_done_tstamp': 1743152410.1520762, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.3933647, 'host_status_query_count': 29, 'worker_start_tstamp': 1743152408.3113096, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [34.5, 91.9, 46.7, 83.8, 59.5, 74.9, 60.9, 70.1, 78.8, 59.5, 44.9, 84.3, 68.2, 59.8, 87.4, 71.6, 93.9, 94.9, 93.4, 93.9, 82.4, 88.3, 89.8, 88.3, 70.8, 70.9, 71.4, 75.0], 'worker_func_cpu_system_time': 959.37, 'worker_func_cpu_user_time': 5645.07, 'worker_func_avg_cpu_usage': 74.63571428571429, 'worker_func_energy_consumption': 421323.8316428571, 'worker_func_sent_net_io': 1676, 'worker_func_recv_net_io': 10375, 'worker_func_rss': 50003968, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 1.9165067672729492, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 394.58, 'worker_func_energy_cores': 379.15, 'worker_func_energy_total': 773.73, 'worker_func_perf_energy': {'pkg': 394.58, 'cores': 379.15, 'total': 773.73}, 'worker_func_perf_energy_pkg': 394.58, 'worker_func_perf_energy_cores': 379.15, 'worker_func_energy_efficiency': 403.7188979514859, 'worker_peak_memory_start': 35905536.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.3801637, 'worker_func_end_tstamp': 1743152410.2819674, 'worker_func_exec_time': 1.90180373, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37511168.0, 'worker_end_tstamp': 1743152410.3894894, 'worker_exec_time': 2.07817984, 'host_result_done_tstamp': 1743152410.457203, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.674749, 'host_status_query_count': 33, 'worker_start_tstamp': 1743152408.444299, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [26.7, 82.7, 40.6, 73.7, 50.2, 65.9, 54.1, 61.2, 76.9, 50.7, 40.2, 75.6, 60.9, 51.5, 81.7, 61.2, 82.8, 83.7, 82.3, 82.8, 72.2, 77.6, 78.5, 77.0, 61.1, 60.8, 61.7, 64.7], 'worker_func_cpu_system_time': 959.49, 'worker_func_cpu_user_time': 5645.87, 'worker_func_avg_cpu_usage': 65.67857142857143, 'worker_func_energy_consumption': 370812.6760714286, 'worker_func_sent_net_io': 5284, 'worker_func_recv_net_io': 12693, 'worker_func_rss': 50176000, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 2.065774917602539, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 394.16, 'worker_func_energy_cores': 377.85, 'worker_func_energy_total': 772.01, 'worker_func_perf_energy': {'pkg': 394.16, 'cores': 377.85, 'total': 772.01}, 'worker_func_perf_energy_pkg': 394.16, 'worker_func_perf_energy_cores': 377.85, 'worker_func_energy_efficiency': 373.7144804216937, 'worker_peak_memory_start': 35962880.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.486588, 'worker_func_end_tstamp': 1743152410.5352252, 'worker_func_exec_time': 2.04863715, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37568512.0, 'worker_end_tstamp': 1743152410.6560411, 'worker_exec_time': 2.21174216, 'host_result_done_tstamp': 1743152410.7614512, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.5022871, 'host_status_query_count': 30, 'worker_start_tstamp': 1743152408.5739381, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [24.0, 89.1, 39.5, 80.3, 52.0, 71.7, 55.2, 64.2, 75.9, 52.3, 36.4, 80.0, 63.0, 52.9, 85.6, 65.7, 90.9, 92.0, 90.3, 91.4, 78.4, 85.1, 86.3, 85.1, 65.3, 65.3, 65.9, 69.4], 'worker_func_cpu_system_time': 959.38, 'worker_func_cpu_user_time': 5645.25, 'worker_func_avg_cpu_usage': 69.75714285714285, 'worker_func_energy_consumption': 393796.5107142857, 'worker_func_sent_net_io': 1676, 'worker_func_recv_net_io': 10375, 'worker_func_rss': 49926144, 'worker_func_vms': 1065660416, 'worker_func_uss': 31375360, 'worker_func_energy_duration': 1.717724084854126, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 348.72, 'worker_func_energy_cores': 334.92, 'worker_func_energy_total': 683.6400000000001, 'worker_func_perf_energy': {'pkg': 348.72, 'cores': 334.92, 'total': 683.6400000000001}, 'worker_func_perf_energy_pkg': 348.72, 'worker_func_perf_energy_cores': 334.92, 'worker_func_energy_efficiency': 397.9917415305129, 'worker_peak_memory_start': 35733504.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.6105525, 'worker_func_end_tstamp': 1743152410.3164053, 'worker_func_exec_time': 1.70585275, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37339136.0, 'worker_end_tstamp': 1743152410.4250462, 'worker_exec_time': 1.85110807, 'host_result_done_tstamp': 1743152410.5589333, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152368.642506, 'host_job_serialize_time': 0.021225, 'func_data_size_bytes': 7200, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000107, 'host_data_upload_time': 2.5e-05, 'host_job_created_time': 0.021755, 'host_status_done_tstamp': 1743152410.2983885, 'host_status_query_count': 26, 'worker_start_tstamp': 1743152408.5650961, 'host_submit_tstamp': 1743152368.664715, 'worker_cold_start': True, 'worker_func_cpu_usage': [27.1, 89.9, 34.4, 89.2, 57.7, 68.8, 57.2, 69.4, 74.2, 58.0, 34.8, 88.1, 67.5, 54.1, 84.2, 73.0, 100.0, 100.0, 98.1, 100.0, 85.2, 93.0, 94.3, 93.1, 71.3, 71.5, 72.2, 76.6], 'worker_func_cpu_system_time': 959.28, 'worker_func_cpu_user_time': 5644.05, 'worker_func_avg_cpu_usage': 74.38928571428572, 'worker_func_energy_consumption': 419856.84803571436, 'worker_func_sent_net_io': 1548, 'worker_func_recv_net_io': 9447, 'worker_func_rss': 49811456, 'worker_func_vms': 1065660416, 'worker_func_uss': 31371264, 'worker_func_energy_duration': 1.532627820968628, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 319.01, 'worker_func_energy_cores': 306.63, 'worker_func_energy_total': 625.64, 'worker_func_perf_energy': {'pkg': 319.01, 'cores': 306.63, 'total': 625.64}, 'worker_func_perf_energy_pkg': 319.01, 'worker_func_perf_energy_cores': 306.63, 'worker_func_energy_efficiency': 408.21391301939997, 'worker_peak_memory_start': 35905536.0, 'function_name': 'randomize_points', 'worker_func_start_tstamp': 1743152408.626406, 'worker_func_end_tstamp': 1743152410.1499276, 'worker_func_exec_time': 1.52352166, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 37511168.0, 'worker_end_tstamp': 1743152410.2590864, 'worker_exec_time': 1.69399023, 'host_result_done_tstamp': 1743152410.3555255, 'host_result_query_count': 0}
#
#
# {'host_job_create_tstamp': 1743152379.4605944, 'host_job_serialize_time': 0.003791, 'func_data_size_bytes': 602610, 'func_module_size_bytes': 6374, 'host_func_upload_time': 0.000102, 'host_data_upload_time': 0.00028, 'host_job_created_time': 0.004282, 'host_status_done_tstamp': 1743152410.9263608, 'host_status_query_count': 36, 'worker_start_tstamp': 1743152408.6917026, 'host_submit_tstamp': 1743152379.4658532, 'worker_cold_start': True, 'worker_func_cpu_usage': [16.9, 73.0, 29.7, 67.2, 40.8, 56.2, 46.1, 50.2, 68.1, 39.6, 32.2, 65.2, 51.2, 42.0, 72.4, 50.5, 73.4, 74.5, 73.0, 73.4, 62.7, 68.0, 68.1, 67.0, 50.5, 50.5, 51.2, 54.2], 'worker_func_cpu_system_time': 959.58, 'worker_func_cpu_user_time': 5646.11, 'worker_func_avg_cpu_usage': 55.99285714285714, 'worker_func_energy_consumption': 316141.8306428571, 'worker_func_sent_net_io': 6992, 'worker_func_recv_net_io': 19662, 'worker_func_rss': 50147328, 'worker_func_vms': 1066266624, 'worker_func_uss': 32043008, 'worker_func_energy_duration': 2.0041987895965576, 'worker_func_energy_source': 'perf', 'worker_func_energy_cpu_percent': 0.0, 'worker_func_energy_pkg': 352.88, 'worker_func_energy_cores': 337.1, 'worker_func_energy_total': 689.98, 'worker_func_perf_energy': {'pkg': 352.88, 'cores': 337.1, 'total': 689.98}, 'worker_func_perf_energy_pkg': 352.88, 'worker_func_perf_energy_cores': 337.1, 'worker_func_energy_efficiency': 344.267247132153, 'worker_peak_memory_start': 36573184.0, 'function_name': 'process_in_circle_points', 'worker_func_start_tstamp': 1743152410.7266092, 'worker_func_end_tstamp': 1743152410.726635, 'worker_func_exec_time': 2.575e-05, 'func_result_size': 21.0, 'worker_result_upload_time': 0.0, 'worker_peak_memory_end': 46665728.0, 'worker_end_tstamp': 1743152410.8529508, 'worker_exec_time': 2.16124821, 'host_result_done_tstamp': 1743152410.9638598, 'host_result_query_count': 0}
#
#
# 301
# 301

# %%
import pandas as pd
import numpy as np


df = pd.DataFrame(stats2)

# Display the table
print(df)

# Optional: If you want to see more details
print("\nDetailed PKG Energy Information:")
print(f"Total PKG Energy: {df['worker_func_perf_energy_pkg'].sum()}")
print(f"Average PKG Energy: {df['worker_func_perf_energy_pkg'].mean()}")
# Out:
#      host_job_create_tstamp  host_job_serialize_time  func_data_size_bytes  \
# 0              1.743152e+09                 0.021225                  7200
# 1              1.743152e+09                 0.021225                  7200
# 2              1.743152e+09                 0.021225                  7200
# 3              1.743152e+09                 0.021225                  7200
# 4              1.743152e+09                 0.021225                  7200
# ..                      ...                      ...                   ...
# 296            1.743152e+09                 0.021225                  7200
# 297            1.743152e+09                 0.021225                  7200
# 298            1.743152e+09                 0.021225                  7200
# 299            1.743152e+09                 0.021225                  7200
# 300            1.743152e+09                 0.003791                602610
#
#      func_module_size_bytes  host_func_upload_time  host_data_upload_time  \
# 0                      6374               0.000107               0.000025
# 1                      6374               0.000107               0.000025
# 2                      6374               0.000107               0.000025
# 3                      6374               0.000107               0.000025
# 4                      6374               0.000107               0.000025
# ..                      ...                    ...                    ...
# 296                    6374               0.000107               0.000025
# 297                    6374               0.000107               0.000025
# 298                    6374               0.000107               0.000025
# 299                    6374               0.000107               0.000025
# 300                    6374               0.000102               0.000280
#
#      host_job_created_time  host_status_done_tstamp  host_status_query_count  \
# 0                 0.021755             1.743152e+09                        1
# 1                 0.021755             1.743152e+09                        1
# 2                 0.021755             1.743152e+09                        1
# 3                 0.021755             1.743152e+09                        1
# 4                 0.021755             1.743152e+09                        1
# ..                     ...                      ...                      ...
# 296               0.021755             1.743152e+09                       29
# 297               0.021755             1.743152e+09                       33
# 298               0.021755             1.743152e+09                       30
# 299               0.021755             1.743152e+09                       26
# 300               0.004282             1.743152e+09                       36
#
#      worker_start_tstamp  ...  worker_func_start_tstamp  \
# 0           1.743152e+09  ...              1.743152e+09
# 1           1.743152e+09  ...              1.743152e+09
# 2           1.743152e+09  ...              1.743152e+09
# 3           1.743152e+09  ...              1.743152e+09
# 4           1.743152e+09  ...              1.743152e+09
# ..                   ...  ...                       ...
# 296         1.743152e+09  ...              1.743152e+09
# 297         1.743152e+09  ...              1.743152e+09
# 298         1.743152e+09  ...              1.743152e+09
# 299         1.743152e+09  ...              1.743152e+09
# 300         1.743152e+09  ...              1.743152e+09
#
#      worker_func_end_tstamp worker_func_exec_time  func_result_size  \
# 0              1.743152e+09              2.939478              21.0
# 1              1.743152e+09              2.400185              21.0
# 2              1.743152e+09              3.068661              21.0
# 3              1.743152e+09              2.999849              21.0
# 4              1.743152e+09              2.249416              21.0
# ..                      ...                   ...               ...
# 296            1.743152e+09              1.901804              21.0
# 297            1.743152e+09              2.048637              21.0
# 298            1.743152e+09              1.705853              21.0
# 299            1.743152e+09              1.523522              21.0
# 300            1.743152e+09              0.000026              21.0
#
#      worker_result_upload_time  worker_peak_memory_end  worker_end_tstamp  \
# 0                          0.0              37507072.0       1.743152e+09
# 1                          0.0              37281792.0       1.743152e+09
# 2                          0.0              37867520.0       1.743152e+09
# 3                          0.0              37396480.0       1.743152e+09
# 4                          0.0              37277696.0       1.743152e+09
# ..                         ...                     ...                ...
# 296                        0.0              37511168.0       1.743152e+09
# 297                        0.0              37568512.0       1.743152e+09
# 298                        0.0              37339136.0       1.743152e+09
# 299                        0.0              37511168.0       1.743152e+09
# 300                        0.0              46665728.0       1.743152e+09
#
#      worker_exec_time  host_result_done_tstamp  host_result_query_count
# 0            3.209268             1.743152e+09                        0
# 1            2.680365             1.743152e+09                        0
# 2            3.366899             1.743152e+09                        0
# 3            3.278707             1.743152e+09                        0
# 4            2.505663             1.743152e+09                        0
# ..                ...                      ...                      ...
# 296          2.078180             1.743152e+09                        0
# 297          2.211742             1.743152e+09                        0
# 298          1.851108             1.743152e+09                        0
# 299          1.693990             1.743152e+09                        0
# 300          2.161248             1.743152e+09                        0
#
# [301 rows x 44 columns]
#
# Detailed PKG Energy Information:
# Total PKG Energy: 194443.28000000003
# Average PKG Energy: 645.9909634551495

# %%
import pandas as pd
import matplotlib.pyplot as plt

 
df = pd.DataFrame(stats2)

# Create the line graph
plt.figure(figsize=(10, 6))
plt.plot(df['Worker_ID'], df['worker_func_perf_energy_pkg'], marker='o', linestyle='-', linewidth=2, markersize=10)
plt.title('PKG Energy by Worker', fontsize=16)
plt.xlabel('Worker ID', fontsize=12)
plt.ylabel('PKG Energy Value', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Add value labels
for x, y in zip(df['Worker_ID'], df['worker_func_perf_energy_pkg']):
    plt.text(x, y, f'{y}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/TFG/lithops/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Worker_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 9
#       7 # Create the line graph
#       8 plt.figure(figsize=(10, 6))
# ----> 9 plt.plot(df['Worker_ID'], df['worker_func_perf_energy_pkg'], marker='o', linestyle='-', linewidth=2, markersize=10)
#      10 plt.title('PKG Energy by Worker', fontsize=16)
#      11 plt.xlabel('Worker ID', fontsize=12)
#
# File ~/Desktop/TFG/lithops/venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/TFG/lithops/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Worker_ID'
